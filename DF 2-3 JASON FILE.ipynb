# %%
import json
from io import StringIO
import pandas as pd
records = [json.loads(line) for line in open(r'C:\Users\Omar\Desktop\task 1 python\Task 2\Task 2\usa.gov_click_data_2.json')]

# %%
dataframe = pd.json_normalize(records)
display(dataframe)
# Out:
#                                                       a   c   nk  \
# 0     Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...  US  1.0
# 1                                GoogleMaps/RochesterNY  US  0.0
# 2     Mozilla/4.0 (Windows NT 6.1; MSIE 8.0; Windows...  US  1.0
# 3     Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8)...  BR  0.0
# 4     Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...  US  0.0
# ...                                                 ...  ..  ...
# 3555  Mozilla/4.0 (Windows NT 6.1; MSIE 9.0; Windows...  US  1.0
# 3556  Mozilla/5.0 (Windows NT 5.1) AppleWebKit/535.1...  US  0.0
# 3557                             GoogleMaps/RochesterNY  US  0.0
# 3558                                     GoogleProducer  US  0.0
# 3559  Mozilla/4.0 (Windows NT 6.1; MSIE 8.0; Windows...  US  0.0
#
#                        tz  gr       g       h             l              al  \
# 0        America/New_York  MA  A6qOVH  wfLQtf       orofrog  en-US,en;q=0.8
# ...

# %%
df= dataframe.drop(columns =['_heartbeat_','kw'],inplace=True)   ##removing last 2 colomns

# %%
display(dataframe)
# Out:
#                                                       a   c   nk  \
# 0     Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...  US  1.0
# 1                                GoogleMaps/RochesterNY  US  0.0
# 2     Mozilla/4.0 (Windows NT 6.1; MSIE 8.0; Windows...  US  1.0
# 3     Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8)...  BR  0.0
# 4     Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...  US  0.0
# ...                                                 ...  ..  ...
# 3555  Mozilla/4.0 (Windows NT 6.1; MSIE 9.0; Windows...  US  1.0
# 3556  Mozilla/5.0 (Windows NT 5.1) AppleWebKit/535.1...  US  0.0
# 3557                             GoogleMaps/RochesterNY  US  0.0
# 3558                                     GoogleProducer  US  0.0
# 3559  Mozilla/4.0 (Windows NT 6.1; MSIE 8.0; Windows...  US  0.0
#
#                        tz  gr       g       h             l              al  \
# 0        America/New_York  MA  A6qOVH  wfLQtf       orofrog  en-US,en;q=0.8
# ...

# %%
df = dataframe.dropna()
df = df.reset_index(drop=True)

# %%
df['web_browser'] =pd.Series([x.split()[0] for x in df.a.dropna()])

# %%
df2 = df['a'].str.extract(r'\(([^()]+)\)')

# %%
##geting opwearting system
df['operating_sys']=pd.Series([x.split(';')[0] for x in df2[0].dropna()])

# %%
df['from_url']=df['r'].str.extract('//([\w\-\.]+)/').fillna('direct')

# %%
df['to_url']=df['u'].str.extract('//([\w\-\.]+)/')

# %%
df
# Out:
#                                                       a   c   nk  \
# 0     Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...  US  1.0
# 1     Mozilla/4.0 (Windows NT 6.1; MSIE 8.0; Windows...  US  1.0
# 2     Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8)...  BR  0.0
# 3     Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...  US  0.0
# 4     Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...  US  0.0
# ...                                                 ...  ..  ...
# 2582  Mozilla/4.0 (Windows NT 6.1; MSIE 7.0; Windows...  US  0.0
# 2583  Mozilla/4.0 (Windows NT 6.1; MSIE 7.0; Windows...  US  0.0
# 2584  Mozilla/4.0 (Windows NT 6.1; MSIE 9.0; Windows...  US  1.0
# 2585  Mozilla/5.0 (Windows NT 5.1) AppleWebKit/535.1...  US  0.0
# 2586  Mozilla/4.0 (Windows NT 6.1; MSIE 8.0; Windows...  US  0.0
#
#                      tz  gr       g       h             l              al  \
# 0      America/New_York  MA  A6qOVH  wfLQtf       orofrog  en-US,en;q=0.8
# ...

# %%
df.rename(columns={'c': 'Country'}, inplace=True)
df.rename(columns={'cy': 'City'}, inplace=True)
df.rename(columns={'tz': 'time zone'}, inplace=True)
df.rename(columns={'r': 'FROM_URL'}, inplace=True)
df.rename(columns={'u': 'TO_URL'}, inplace=True)
df.rename(columns={'ll': 'Longitude and Latitude'}, inplace=True)
df.rename(columns={'hc': 'Time_in'}, inplace=True)
df.rename(columns={'t': 'Time_out'}, inplace=True)

# %%
df['Longtuide']=df['Longitude and Latitude'].apply(str).str.strip('[]').str.split(',', expand=True)[0]
df['Latituide']=df['Longitude and Latitude'].apply(str).str.strip('[]').str.split(',', expand=True)[1]
## splitting attitude and lattitude

# %%
df= df.drop(columns =['nk','gr','Longitude and Latitude','h','l','al','hh','g','FROM_URL','TO_URL'])

# %%
del df['a']

# %%
df ###final dataframe for second csv file
# Out:
#      Country          time zone      Time_out       Time_in           City  \
# 0         US   America/New_York  1.331923e+09  1.331823e+09        Danvers
# 1         US   America/New_York  1.331923e+09  1.331920e+09     Washington
# 2         BR  America/Sao_Paulo  1.331923e+09  1.331923e+09           Braz
# 3         US   America/New_York  1.331923e+09  1.273672e+09     Shrewsbury
# 4         US   America/New_York  1.331923e+09  1.273673e+09     Shrewsbury
# ...      ...                ...           ...           ...            ...
# 2582      US   America/New_York  1.331927e+09  1.273672e+09     Shrewsbury
# 2583      US   America/New_York  1.331927e+09  1.273673e+09     Shrewsbury
# 2584      US   America/New_York  1.331927e+09  1.301298e+09        Paramus
# 2585      US    America/Chicago  1.331927e+09  1.307530e+09  Oklahoma City
# 2586      US   America/New_York  1.331927e+09  1.312898e+09        Mc Lean
#
#       web_browser   operating_sys               from_url  \
# ...
